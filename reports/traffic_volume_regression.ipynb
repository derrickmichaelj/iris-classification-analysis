# %% [markdown]
# Dataset:
# https://archive.ics.uci.edu/dataset/492/metro+interstate+traffic+volume

# %% [markdown]
# ## Infering Relationships Between Traffic Volume and Weather, Temporal Data

# %%
# Package Imports
import pandas as pd
from ucimlrepo import fetch_ucirepo
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Summary

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Methods
#
# #### Data
#
# #### Analysis

# %% [markdown]
# ## Results & Discussion

# %%
# Data Import
metro_interstate_traffic_volume = fetch_ucirepo(id=492)

X = metro_interstate_traffic_volume.data.features
y = metro_interstate_traffic_volume.data.targets

# metadata
# print(metro_interstate_traffic_volume.metadata)

# variable information
# print(metro_interstate_traffic_volume.variables)

# %%
# Splitting data_time to time and weekday
X['date_time'] = pd.to_datetime(X['date_time'])

X['time'] = X['date_time'].dt.time

X['weekday'] = X['date_time'].dt.weekday < 5
X['weekday'] = X['weekday'].astype(int)

X = X.drop('date_time', axis = 1)

X
# Out:
# C:\Users\derri\AppData\Local\Temp\ipykernel_6940\1675130431.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['date_time'] = pd.to_datetime(X['date_time'])
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0         NaN  288.28      0.0      0.0          40        Clouds
# 1         NaN  289.36      0.0      0.0          75        Clouds
# 2         NaN  289.58      0.0      0.0          90        Clouds
# 3         NaN  290.13      0.0      0.0          90        Clouds
# 4         NaN  291.14      0.0      0.0          75        Clouds
# ...       ...     ...      ...      ...         ...           ...
# 48199     NaN  283.45      0.0      0.0          75        Clouds
# ...

# %%
# Train/Test Split
X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, test_size=0.3, random_state=123
)

# %% [markdown]
# Consider separating `date_time` into time variable, as well as one classifying each observation as weekday/weekend-day

# %%
# Preprocessing
traffic_preprocessor = make_column_transformer(
    
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Preprocessing
# ----> 2 traffic_preprocessor = make_column_transformer(
#       3
#       4 )
#
# File c:\Users\derri\miniforge3\Lib\site-packages\sklearn\compose\_column_transformer.py:1498, in make_column_transformer(remainder, sparse_threshold, n_jobs, verbose, verbose_feature_names_out, force_int_remainder_cols, *transformers)
#    1385 """Construct a ColumnTransformer from the given transformers.
#    1386
#    1387 This is a shorthand for the ColumnTransformer constructor; it does not
#    (...)   1494                                  ['categorical_column'])])
#    1495 """
#    1496 # transformer_weights keyword is not passed through because the user
#    1497 # would need to know the automatically generated names of the transformers
# ...

# %% [markdown]
# ## References
